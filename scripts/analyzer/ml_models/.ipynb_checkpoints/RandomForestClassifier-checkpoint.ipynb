# %% [markdown]
# # This program attempts to predict the mutation score

# %%
from sklearn import datasets
import pandas as pd

# %% [markdown]
# ## Read DataFrame

# %%
df = pd.read_json("../old_output_with_functions.json")
list(df.columns.values)
# Out:
# ['file',
#  'pattern',
#  'check_id',
#  'pattern_detailes',
#  'function_name',
#  'function_scope',
#  'mutants',
#  'mutation_score']

# %% [markdown]
# **Dropping all mutation_score with 'NA' values**

# %%
df = df.dropna()

# %%
df
# Out:
#                                                   file  \
# 1    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 2    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 3    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 4    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 5    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# ..                                                 ...
# 186  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 187  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 188  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 189  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 190  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
#
#                                                pattern  check_id  \
# 1                                       .//FunctionDef    [F001]
# 2                                       .//FunctionDef    [F001]
# 3                                       .//FunctionDef    [F001]
# 4                                       .//FunctionDef    [F001]
# 5                                       .//FunctionDef    [F001]
# ..                                                 ...       ...
# 186  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 187  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 188  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 189  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 190  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
#
#                                       pattern_detailes   function_name  \
# 1    {'lineno': 21, 'coloffset': 0, 'linematch': 'd...     bubble_sort
# 2    {'lineno': 41, 'coloffset': 0, 'linematch': 'd...  insertion_sort
# 3    {'lineno': 63, 'coloffset': 0, 'linematch': 'd...           merge
# 4    {'lineno': 96, 'coloffset': 0, 'linematch': 'd...      merge_sort
# 5    {'lineno': 104, 'coloffset': 0, 'linematch': '...      quick_sort
# ..                                                 ...             ...
# 186  {'lineno': 64, 'coloffset': 4, 'linematch': 'a...     listsorting
# 187  {'lineno': 65, 'coloffset': 4, 'linematch': 'r...     listsorting
# 188  {'lineno': 68, 'coloffset': 4, 'linematch': 'd...     listsorting
# 189  {'lineno': 77, 'coloffset': 4, 'linematch': 't...     listsorting
# 190  {'lineno': 78, 'coloffset': 4, 'linematch': 'p...     listsorting
#
#     function_scope                                            mutants  \
# 1            21-38  [{'name': 'Mutant #1', 'line': 24, 'descriptio...
# 2            41-60  [{'name': 'Mutant #18', 'line': 44, 'descripti...
# 3            63-93  [{'name': 'Mutant #36', 'line': 67, 'descripti...
# 4           96-101  [{'name': 'Mutant #60', 'line': 98, 'descripti...
# 5          104-118  [{'name': 'Mutant #65', 'line': 106, 'descript...
# ..             ...                                                ...
# 186          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 187          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 188          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 189          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 190          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
#
#      mutation_score
# 1         70.588235
# 2         44.444444
# 3         62.500000
# 4         60.000000
# 5         50.000000
# ..              ...
# 186        0.000000
# 187        0.000000
# 188        0.000000
# 189        0.000000
# 190        0.000000
#
# [139 rows x 8 columns]

# %%
average_mutation_score = df.groupby('pattern')['mutation_score'].mean()

# %%
result_df = pd.DataFrame({'check_id': average_mutation_score.index, 'average_mutation_score': average_mutation_score.values})
print(result_df)
# Out:
#                                              check_id  average_mutation_score
# 0                                      .//FunctionDef               26.099799
# 1                             .//FunctionDef/body//If               57.975113
# 2       .//FunctionDef[not(contains(@name, "test_"))]               26.099799
# 3                 //Compare/ops/Is | //Compare/ops/Eq               48.333333
# 4                          //FunctionDef//For[.//For]               70.588235
# 5                    //FunctionDef//If/descendant::If               50.000000
# 6   //FunctionDef//If/following-sibling::If | //Fu...               62.500000
# 7   //FunctionDef[//(If/following-sibling::For | F...               48.471055
# 8   //FunctionDef[@type='str']/body/* | //Function...               24.411033
# 9      //FunctionDef[body//comprehension/target/Name]                0.000000
# 10  //FunctionDef[not(args/arg/annotation) or not(...               26.099799

# %% [markdown]
# ## Data Preprocessing
#
# * Label Encoding 'pattern'
# * Categorize 'mutation_score'

# %%
#use LabelEncoding to encode all string data

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['pattern'])
# Out:
# LabelEncoder()

# %%
for idx, row in df.iterrows():
  pattern = row['pattern']
  encoded_pattern = le.transform([pattern])[0]
  df.loc[idx, 'pattern_encoded'] = encoded_pattern

# %% [markdown]
# **Unique patterns and their encoded labels**

# %%
unique_patterns = df.groupby('pattern')['pattern_encoded'].first().reset_index()

# Loop through unique patterns and print each on a single line
for index, row in unique_patterns.iterrows():
  pattern = row['pattern']
  encoded_label = row['pattern_encoded']
  print(f"{pattern}: {encoded_label}")
# Out:
# .//FunctionDef: 0.0
# .//FunctionDef/body//If: 1.0
# .//FunctionDef[not(contains(@name, "test_"))]: 2.0
# //Compare/ops/Is | //Compare/ops/Eq: 3.0
# //FunctionDef//For[.//For]: 4.0
# //FunctionDef//If/descendant::If: 5.0
# //FunctionDef//If/following-sibling::If | //FunctionDef//If/following-sibling::Elif | //FunctionDef//If/following-sibling::Else: 6.0
# //FunctionDef[//(If/following-sibling::For | For/following-sibling::If)]: 7.0
# //FunctionDef[@type='str']/body/* | //FunctionDef[@type='str']/body/Return: 8.0
# //FunctionDef[body//comprehension/target/Name]: 9.0
# //FunctionDef[not(args/arg/annotation) or not(returns)]: 10.0

# %%
# catagorize mutation score 
low_threshold = 30
medium_threshold = 60

def map_to_category(score):
    """Maps a mutation score to a category (high, medium,low)"""
    if score < low_threshold:
        return "low"
    elif score < medium_threshold:
        return "medium"
    else:
        return "high"

# %%
df = df.assign(mutation_category = df['mutation_score'].apply(map_to_category))

# %% [markdown]
# **Current Dataset**

# %%
df
# Out:
#                                                   file  \
# 1    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 2    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 3    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 4    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 5    /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# ..                                                 ...
# 186  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 187  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 188  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 189  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
# 190  /Users/jaclynpham/AstuteSource/SEERS/scripts/a...
#
#                                                pattern  check_id  \
# 1                                       .//FunctionDef    [F001]
# 2                                       .//FunctionDef    [F001]
# 3                                       .//FunctionDef    [F001]
# 4                                       .//FunctionDef    [F001]
# 5                                       .//FunctionDef    [F001]
# ..                                                 ...       ...
# 186  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 187  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 188  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 189  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
# 190  //FunctionDef[@type='str']/body/* | //Function...  [CML001]
#
#                                       pattern_detailes   function_name  \
# 1    {'lineno': 21, 'coloffset': 0, 'linematch': 'd...     bubble_sort
# 2    {'lineno': 41, 'coloffset': 0, 'linematch': 'd...  insertion_sort
# 3    {'lineno': 63, 'coloffset': 0, 'linematch': 'd...           merge
# 4    {'lineno': 96, 'coloffset': 0, 'linematch': 'd...      merge_sort
# 5    {'lineno': 104, 'coloffset': 0, 'linematch': '...      quick_sort
# ..                                                 ...             ...
# 186  {'lineno': 64, 'coloffset': 4, 'linematch': 'a...     listsorting
# 187  {'lineno': 65, 'coloffset': 4, 'linematch': 'r...     listsorting
# 188  {'lineno': 68, 'coloffset': 4, 'linematch': 'd...     listsorting
# 189  {'lineno': 77, 'coloffset': 4, 'linematch': 't...     listsorting
# 190  {'lineno': 78, 'coloffset': 4, 'linematch': 'p...     listsorting
#
#     function_scope                                            mutants  \
# 1            21-38  [{'name': 'Mutant #1', 'line': 24, 'descriptio...
# 2            41-60  [{'name': 'Mutant #18', 'line': 44, 'descripti...
# 3            63-93  [{'name': 'Mutant #36', 'line': 67, 'descripti...
# 4           96-101  [{'name': 'Mutant #60', 'line': 98, 'descripti...
# 5          104-118  [{'name': 'Mutant #65', 'line': 106, 'descript...
# ..             ...                                                ...
# 186          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 187          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 188          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 189          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
# 190          45-78  [{'name': 'Mutant #183', 'line': 46, 'descript...
#
#      mutation_score  pattern_encoded mutation_category
# 1         70.588235              0.0              high
# 2         44.444444              0.0            medium
# 3         62.500000              0.0              high
# 4         60.000000              0.0              high
# 5         50.000000              0.0            medium
# ..              ...              ...               ...
# 186        0.000000              8.0               low
# 187        0.000000              8.0               low
# 188        0.000000              8.0               low
# 189        0.000000              8.0               low
# 190        0.000000              8.0               low
#
# [139 rows x 10 columns]

# %%
#Counts of mutation score categories
category_counts = df['mutation_category'].value_counts()
print(category_counts)
# Out:
# mutation_category
# low       62
# high      60
# medium    17
# Name: count, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
#independent and dependent variables
X=df[['pattern_encoded']]
y=df['mutation_category']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.30, random_state=42)

# %% [markdown]
# ## Training of Model

# %%
#importing random forest classifier from assemble module
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# %%
#creating a RF classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)
print(y_pred)
# Out:
# ['low' 'high' 'high' 'low' 'medium' 'low' 'low' 'high' 'low' 'low' 'low'
#  'low' 'low' 'low' 'low' 'high' 'low' 'high' 'low' 'low' 'high' 'low'
#  'low' 'low' 'low' 'high' 'low' 'high' 'low' 'low' 'low' 'low' 'low'
#  'high' 'low' 'low' 'low' 'low' 'low' 'low' 'low' 'high']

# %%
print("All actual vs. predicted categories:")
for i in range(len(y_test)):
  print(f"Sample {i+1}: Actual - {y_test.iloc[i]}, Predicted - {y_pred[i]}")
# Out:
# All actual vs. predicted categories:
# Sample 1: Actual - low, Predicted - low
# Sample 2: Actual - high, Predicted - high
# Sample 3: Actual - high, Predicted - high
# Sample 4: Actual - low, Predicted - low
# Sample 5: Actual - medium, Predicted - medium
# Sample 6: Actual - low, Predicted - low
# Sample 7: Actual - low, Predicted - low
# Sample 8: Actual - medium, Predicted - high
# Sample 9: Actual - low, Predicted - low
# Sample 10: Actual - low, Predicted - low
# Sample 11: Actual - low, Predicted - low
# Sample 12: Actual - low, Predicted - low
# Sample 13: Actual - high, Predicted - low
# Sample 14: Actual - low, Predicted - low
# Sample 15: Actual - high, Predicted - low
# Sample 16: Actual - medium, Predicted - high
# Sample 17: Actual - low, Predicted - low
# Sample 18: Actual - high, Predicted - high
# Sample 19: Actual - low, Predicted - low
# Sample 20: Actual - low, Predicted - low
# Sample 21: Actual - medium, Predicted - high
# Sample 22: Actual - low, Predicted - low
# Sample 23: Actual - medium, Predicted - low
# Sample 24: Actual - medium, Predicted - low
# Sample 25: Actual - high, Predicted - low
# Sample 26: Actual - high, Predicted - high
# Sample 27: Actual - low, Predicted - low
# Sample 28: Actual - high, Predicted - high
# Sample 29: Actual - high, Predicted - low
# Sample 30: Actual - medium, Predicted - low
# Sample 31: Actual - low, Predicted - low
# Sample 32: Actual - low, Predicted - low
# Sample 33: Actual - low, Predicted - low
# Sample 34: Actual - medium, Predicted - high
# Sample 35: Actual - low, Predicted - low
# Sample 36: Actual - high, Predicted - low
# Sample 37: Actual - high, Predicted - low
# Sample 38: Actual - high, Predicted - low
# Sample 39: Actual - medium, Predicted - low
# Sample 40: Actual - high, Predicted - low
# Sample 41: Actual - medium, Predicted - low
# Sample 42: Actual - high, Predicted - high

# %% [markdown]
# #confusion matrix
#
# how many times it predicts accurately?

# %% [markdown]
# ## Evaluating model performance

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy on test set: {accuracy:.4f}")
# Out:
# Model accuracy on test set: 0.5952

# %% [markdown]
# **Note:**
# At the moment, the model accuracy on the test set indicates that it's not consistently accurate across all data points. Here are some reasons I suspect:
# * Limited Data
# * Feature Selection
# * Model Complexity
